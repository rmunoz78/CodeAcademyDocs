# %% [markdown]
# <a href="https://colab.research.google.com/github/rmunoz78/CodeAcademyDocs/blob/main/Marriot_Cancellation_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Marriot Cancellation
# ## PROBLEM STATEMENT
# Marriott International's text: Deploying AI Across Hotel Brands in Singapore presents the case that the hotel industry is part of the revolution movement based on the use of artificial intelligence. The text additionally presented us with some of the initiatives with which they are working and presented us with some of their market segments.
# Based on this information, we decided to present a solution to the Marriott group based on artificial intelligence to generate business intelligence, not only in the Singapore sector, but around the world.
#
# ## OBJECTIVES
# The goal of this project will be to develop a prediction model to determine if customers' reservations are at risk of cancellation, as well as identify key factors to reduce or even eliminate this number.
#
# ## Data Collection and Preparation
#
# ### Data dictionary
# - hotel [Categorical]: Hotel's Name and Location
# - is_canceled [Categorical]: If the reservation was cancelled (1) or not (0)
# - lead_time [Numeric]: Days in advance with which the reservation was made
# - arrival_date_year [Date]: Year of the Arrival Date
# - arrival_date_month [Date]: Month of the Arrival Date
# - arrival_date_week_number [Date]: Calendar Week of the Arrival Date
# - arrival_date_day_of_month [Date]: Day of the Month of the Arrival Date
# - stays_in_weekend_nights [Numeric]: Number of weekend days that the guest stayed or booked
# - stays_in_week_nights[Numeric]: Number of weekdays days that the guest stayed or booked
# - adults [Numeric]: Number of adults
# - children [Numeric]: Number of Children
# - babies [Numeric]: Number of Babies
# - meal [Categorical]: Type of meal booked
# - country [Categorical]: Country of origin
# - market_segment [Categorical]: Reservation Channel
# - distribution_channel [Categorical]: Distribution Channel
# - is_repeated_guest [Categorical]: If the guest has previously stayed (1) or not (0)
# - previous_cancellations [Categorical]: If the guest has previously cancelled (1) or not (0)
# - previous_bookings_not_canceled [Numeric]: Number of previous bookings not canceled
# - reserved_room_type [Categorical]: Type of room reserved
# - assigned_room_type [Categorical]: Type of room assigned
# - booking_changes [Numeric]: Number of booking changes
# - deposit_type [Categorical]: Deposit Type
# - agent [Categorical]: Id of the agent used
# - company [Categorical]: Id of the booking company
# - days_in_waiting_list [Numeric]: Number of days in the waiting list
# - customer_type [Categorical]: Type of booking (Transient, Transient-Party, Contract or Group)
# - adr [Numeric]: Average Dauly Rate
# - required_car_parking_spaces [Categorical]: Number of parking areas necessary for the costumer
# - total_of_special_requests [Numeric]: Number of special requests
# - reservation_status [Categorical]: Reservation status category (Check-Out, No-Show or Canceled)
# - reservation_status_date [Date]: Date of the Reservation Status Change

# %% [markdown]
# ### Library Import

# %%
# !pip install pycountry
# Out:
# Collecting pycountry
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 16.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from pycountry) (67.7.2)
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (pyproject.toml) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681832 sha256=a022b3f432813f51cdff0078ec7520569f52041ac805ce068be81f8e1947822e
#   Stored in directory: /root/.cache/pip/wheels/03/57/cc/290c5252ec97a6d78d36479a3c5e5ecc76318afcb241ad9dbe
# Successfully built pycountry
# Installing collected packages: pycountry
# Successfully installed pycountry-22.3.5

# %%
import warnings

warnings.filterwarnings("ignore")
# Libraries to help with reading and manipulating data
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import numpy as np
import math

# libaries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Libraries to tune model, get different metric scores, and split data
from sklearn import metrics
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

from sklearn.impute import KNNImputer
from sklearn.pipeline import Pipeline, make_pipeline

#libraries to help with model building
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    AdaBoostClassifier,
    GradientBoostingClassifier,
    RandomForestClassifier,
    BaggingClassifier)
from xgboost import XGBClassifier

# to suppress scientifiv notations
pd.set_option('display.float_format', lambda x: '%.3f' % x)

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Reading the CSV data file
raw_df = pd.read_excel('/content/drive/MyDrive/Maestria/6 Trimestre/Equipo_1/Proyecto Integrador/JWM_Dataset.xlsx')

# %%
data = raw_df.copy()
# First 5 Rows
data.head()
# Out:
#                                                hotel  is_canceled  lead_time  \
# 0  Orlando International Drive/Convention Center ...            0        342
# 1  Protea Hotel by Marriott Cape Town Sea Point C...            0        737
# 2  Sheraton Lima Hotel & Convention Center Lima, ...            0          7
# 3                Greensboro Courtyard Greensboro, NC            0         13
# 4  Marriott Puerto Vallarta Resort & Spa Puerto V...            0         14
#
#    arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0               2017               July                        27
# 1               2017               July                        27
# 2               2017               July                        27
# 3               2017               July                        27
# 4               2017               July                        27
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# 1                          1                        0                     0
# 2                          1                        0                     1
# 3                          1                        0                     1
# 4                          1                        0                     2
#
#    adults  children  babies meal country market_segment distribution_channel  \
# 0       2     0.000       0   BB     PRT         Direct               Direct
# 1       2     0.000       0   BB     PRT         Direct               Direct
# 2       1     0.000       0   BB     GBR         Direct               Direct
# 3       1     0.000       0   BB     GBR      Corporate            Corporate
# 4       2     0.000       0   BB     GBR      Online TA                TA/TO
#
#    is_repeated_guest  previous_cancellations  previous_bookings_not_canceled  \
# 0                  0                       0                               0
# 1                  0                       0                               0
# 2                  0                       0                               0
# 3                  0                       0                               0
# 4                  0                       0                               0
#
#   reserved_room_type assigned_room_type  booking_changes deposit_type   agent  \
# 0                  C                  C                3   No Deposit     NaN
# 1                  C                  C                4   No Deposit     NaN
# 2                  A                  C                0   No Deposit     NaN
# 3                  A                  A                0   No Deposit 304.000
# 4                  A                  A                0   No Deposit 240.000
#
#    company  days_in_waiting_list customer_type    adr  \
# 0      NaN                     0     Transient  0.000
# 1      NaN                     0     Transient  0.000
# 2      NaN                     0     Transient 75.000
# 3      NaN                     0     Transient 75.000
# 4      NaN                     0     Transient 98.000
#
#    required_car_parking_spaces  total_of_special_requests reservation_status  \
# 0                            0                          0          Check-Out
# 1                            0                          0          Check-Out
# 2                            0                          0          Check-Out
# 3                            0                          0          Check-Out
# 4                            0                          1          Check-Out
#
#   reservation_status_date
# 0              2017-07-01
# 1              2017-07-01
# 2              2017-07-02
# 3              2017-07-02
# 4              2017-07-03

# %%
# Last 5 Rows
data.tail()
# Out:
#                                                     hotel  is_canceled  \
# 118986           Chicago O'Hare Courtyard Des Plaines, IL            0
# 118987  Courtyard by Marriott Toulouse Airport Toulous...            0
# 118988               The Ritz-Carlton, Tokyo Tokyo, Japan            0
# 118989                   The St. Regis Osaka Osaka, Japan            0
# 118990            Leipzig Marriott Hotel Leipzig, Germany            0
#
#         lead_time  arrival_date_year arrival_date_month  \
# 118986         23               2019             August
# 118987        102               2019             August
# 118988         34               2019             August
# 118989        109               2019             August
# 118990        205               2019             August
#
#         arrival_date_week_number  arrival_date_day_of_month  \
# 118986                        35                         30
# 118987                        35                         31
# 118988                        35                         31
# 118989                        35                         31
# 118990                        35                         29
#
#         stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# 118986                        2                     5       2     0.000
# 118987                        2                     5       3     0.000
# 118988                        2                     5       2     0.000
# 118989                        2                     5       2     0.000
# 118990                        2                     7       2     0.000
#
#         babies meal country market_segment distribution_channel  \
# 118986       0   BB     BEL  Offline TA/TO                TA/TO
# 118987       0   BB     FRA      Online TA                TA/TO
# 118988       0   BB     DEU      Online TA                TA/TO
# 118989       0   BB     GBR      Online TA                TA/TO
# 118990       0   HB     DEU      Online TA                TA/TO
#
#         is_repeated_guest  previous_cancellations  \
# 118986                  0                       0
# 118987                  0                       0
# 118988                  0                       0
# 118989                  0                       0
# 118990                  0                       0
#
#         previous_bookings_not_canceled reserved_room_type assigned_room_type  \
# 118986                               0                  A                  A
# 118987                               0                  E                  E
# 118988                               0                  D                  D
# 118989                               0                  A                  A
# 118990                               0                  A                  A
#
#         booking_changes deposit_type   agent  company  days_in_waiting_list  \
# 118986                0   No Deposit 394.000      NaN                     0
# 118987                0   No Deposit   9.000      NaN                     0
# 118988                0   No Deposit   9.000      NaN                     0
# 118989                0   No Deposit  89.000      NaN                     0
# 118990                0   No Deposit   9.000      NaN                     0
#
#        customer_type     adr  required_car_parking_spaces  \
# 118986     Transient  96.140                            0
# 118987     Transient 225.430                            0
# 118988     Transient 157.710                            0
# 118989     Transient 104.400                            0
# 118990     Transient 151.200                            0
#
#         total_of_special_requests reservation_status reservation_status_date
# 118986                          0          Check-Out              2019-09-06
# 118987                          2          Check-Out              2019-09-07
# 118988                          4          Check-Out              2019-09-07
# 118989                          0          Check-Out              2019-09-07
# 118990                          2          Check-Out              2019-09-07

# %% [markdown]
# #### Understand the shape of the dataset.

# %%
data.shape
# Out:
# (118991, 32)

# %% [markdown]
# * The dataset has 118991 rows and 32 columns

# %% [markdown]
# #### Check the data types of the columns for the dataset.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118991 entries, 0 to 118990
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           118991 non-null  object
#  1   is_canceled                     118991 non-null  int64
#  2   lead_time                       118991 non-null  int64
#  3   arrival_date_year               118991 non-null  int64
#  4   arrival_date_month              118991 non-null  object
#  5   arrival_date_week_number        118991 non-null  int64
#  6   arrival_date_day_of_month       118991 non-null  int64
#  7   stays_in_weekend_nights         118991 non-null  int64
#  8   stays_in_week_nights            118991 non-null  int64
#  9   adults                          118991 non-null  int64
#  10  children                        118987 non-null  float64
#  11  babies                          118991 non-null  int64
#  12  meal                            118991 non-null  object
#  13  country                         118503 non-null  object
#  14  market_segment                  118991 non-null  object
#  15  distribution_channel            118991 non-null  object
#  16  is_repeated_guest               118991 non-null  int64
#  17  previous_cancellations          118991 non-null  int64
#  18  previous_bookings_not_canceled  118991 non-null  int64
#  19  reserved_room_type              118991 non-null  object
#  20  assigned_room_type              118991 non-null  object
#  21  booking_changes                 118991 non-null  int64
#  22  deposit_type                    118991 non-null  object
#  23  agent                           102662 non-null  float64
#  24  company                         6796 non-null    float64
#  25  days_in_waiting_list            118991 non-null  int64
#  26  customer_type                   118991 non-null  object
#  27  adr                             118991 non-null  float64
#  28  required_car_parking_spaces     118991 non-null  int64
#  29  total_of_special_requests       118991 non-null  int64
#  30  reservation_status              118991 non-null  object
#  31  reservation_status_date         118991 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(16), object(11)
# memory usage: 29.1+ MB

# %%
Cols_Num = ["lead_time","stays_in_weekend_nights","stays_in_week_nights","adults","children","babies","previous_cancellations","booking_changes","previous_bookings_not_canceled","days_in_waiting_list","adr","required_car_parking_spaces","total_of_special_requests"]
Cols_Cat = ["hotel","is_canceled","customer_type","is_repeated_guest","meal","country","market_segment","distribution_channel","reserved_room_type","assigned_room_type","deposit_type","agent","company","reservation_status"]
Cols_Date = ["arrival_date_year","arrival_date_month","arrival_date_week_number","arrival_date_day_of_month","reservation_status_date"]

# %%
print("Number of Numeric Columns:",len(Cols_Num))
print("Number of Categorical Columns:",len(Cols_Cat))
print("Number of Date Columns:",len(Cols_Date))
# Out:
# Number of Numeric Columns: 13
# Number of Categorical Columns: 14
# Number of Date Columns: 5

# %%
# Count missing values in each column
missing_count = data.isna().sum()

# Filter columns with missing values
columns_with_missing = missing_count[missing_count > 0]

# Print the number of columns with missing data and their names
print(f'Number of columns with missing data: {len(columns_with_missing)}')
print('Columns with missing data:')
for column_name, missing_value_count in columns_with_missing.iteritems():
    print(f'{column_name}: {missing_value_count} [{np.round(missing_value_count*100/data.shape[0],3)}%]')
# Out:
# Number of columns with missing data: 4
# Columns with missing data:
# children: 4 [0.003%]
# country: 488 [0.41%]
# agent: 16329 [13.723%]
# company: 112195 [94.289%]

# %% [markdown]
# We can drop the company column as it is missing over 94% of the data, which means no relevant information is provided by it

# %%
data.drop('company',axis=1, inplace = True)
Cols_Cat.remove('company')

# %% [markdown]
# ### Summary of the dataset.
# #### Numeric Features

# %%
data.describe().T
# Out:
#                                     count     mean     std      min      25%  \
# is_canceled                    118991.000    0.369   0.483    0.000    0.000
# lead_time                      118991.000  103.766 106.679    0.000   18.000
# arrival_date_year              118991.000 2018.159   0.707 2017.000 2018.000
# arrival_date_week_number       118991.000   27.184  13.609    1.000   16.000
# arrival_date_day_of_month      118991.000   15.787   8.778    1.000    8.000
# stays_in_weekend_nights        118991.000    0.929   0.999    0.000    0.000
# stays_in_week_nights           118991.000    2.502   1.910    0.000    1.000
# adults                         118991.000    1.856   0.580    0.000    2.000
# children                       118987.000    0.104   0.399    0.000    0.000
# babies                         118991.000    0.008   0.097    0.000    0.000
# is_repeated_guest              118991.000    0.030   0.172    0.000    0.000
# previous_cancellations         118991.000    0.086   0.843    0.000    0.000
# previous_bookings_not_canceled 118991.000    0.138   1.500    0.000    0.000
# booking_changes                118991.000    0.222   0.653    0.000    0.000
# agent                          102662.000   86.788 110.806    1.000    9.000
# days_in_waiting_list           118991.000    2.329  17.624    0.000    0.000
# adr                            118991.000  101.938  50.560   -6.380   69.855
# required_car_parking_spaces    118991.000    0.063   0.245    0.000    0.000
# total_of_special_requests      118991.000    0.572   0.793    0.000    0.000
#
#                                     50%      75%      max
# is_canceled                       0.000    1.000    1.000
# lead_time                        69.000  160.000  737.000
# arrival_date_year              2018.000 2019.000 2019.000
# arrival_date_week_number         28.000   38.000   53.000
# arrival_date_day_of_month        16.000   23.000   31.000
# stays_in_weekend_nights           1.000    2.000   19.000
# stays_in_week_nights              2.000    3.000   50.000
# adults                            2.000    2.000   55.000
# children                          0.000    0.000   10.000
# babies                            0.000    0.000   10.000
# is_repeated_guest                 0.000    0.000    1.000
# previous_cancellations            0.000    0.000   26.000
# previous_bookings_not_canceled    0.000    0.000   72.000
# booking_changes                   0.000    0.000   21.000
# agent                            14.000  229.000  535.000
# days_in_waiting_list              0.000    0.000  391.000
# adr                              95.000  126.000 5400.000
# required_car_parking_spaces       0.000    0.000    8.000
# total_of_special_requests         0.000    1.000    5.000

# %% [markdown]
# Based on the provided data table, here are some observations and insights:
# 1. is_canceled:
#
#   *   It is a binary variable, indicating whether a booking was canceled (1) or not (0).
#   *   Approximately 36.9% of the bookings in the dataset were canceled.
# 2. lead_time:
#
#   *   The lead_time column represents the number of days between booking and arrival.
#   *   The data is right-skewed, with a large standard deviation (106.679) relative to the mean (103.766), indicating a wide spread of lead times.
#   *   The majority of lead times fall below the 75th percentile (160.000), but there are some long lead times, with a maximum of 737.000 days.
# 3. arrival_date_year:
#
#   *   This variable indicates the year of arrival.
#   *   The data is concentrated mostly in the years 2018 and 2019.
# 4. arrival_date_week_number:
#
#   *   It represents the week number of the arrival date.
#   *   The data spans from week 1 to week 53, with an average week number of approximately 27.184.
# 5. arrival_date_day_of_month:
#
#   *   This variable indicates the day of the month for the arrival date.
#   *   The data ranges from day 1 to day 31, with an average day of approximately 15.787.
# 6. stays_in_weekend_nights:
#
#   *   Most guests don't stay over the weekend, as indicated by the mean of 0.929.
#   *   The data is positively skewed, with a maximum of 19 weekend nights but a median of 1.000.
#
# 7. stays_in_week_nights:
#
#   *   The majority of bookings involve stays of 1 to 3 weeknights, with an average of 2.502 nights.
#   *   There are some outliers with a maximum of 50 weeknights.
#
# 8. adults:
#
#   *   Most bookings have 2 adults.
#   *   There are outliers with a maximum of 55 adults.
#
# 9. children:
#
#   *   The majority of bookings have no children (mean of 0.104), but some have up to 10 children.
# 10. babies:
#
#   *   Most bookings have no babies (mean of 0.008).
#   *   There is very little variation in this column.
# 11. is_repeated_guest:
#
#   *   It is a binary variable indicating whether the guest is a repeated guest (1) or not (0).
#   *   Approximately 3% of the bookings are from repeated guests.
# 12. previous_cancellations:
#
#   *   Most bookings have no previous cancellations (mean of 0.086).
#   *   There are outliers with a maximum of 26 previous cancellations.
# 13. booking_changes:
#
#   *   Most bookings have no booking changes (mean of 0.222).
#   *   There are outliers with a maximum of 21 booking changes.
# 14. agent:
#
#   *   The agent column indicates the ID of the travel agent associated with the booking.
#   *   This column does not give any statistical data. It can be removed
# 15. previous_bookings_not_canceled:
#
#   *   Most bookings have no previous bookings that were not canceled (mean of 0.138).
#   *   There are outliers with a maximum of 72 previous bookings not canceled.
# 16. days_in_waiting_list:
#
#   *   Most bookings have no days in the waiting list (mean of 2.329), but there are some outliers with a maximum of 391 days.
# 17. adr (Average Daily Rate):
#
#   *   The average daily rate has a mean of 101.938, with a relatively high standard deviation (50.560), indicating variability in pricing.
#   *   The minimum value is negative (-6.380), suggesting that some bookings may have received discounts or special rates.
#   *   The data is positively skewed, with a maximum of 5400.000.
# 18. required_car_parking_spaces:
#
#   *   Most bookings do not require car parking spaces (mean of 0.063).
#   *   There are outliers with a maximum of 8 required car parking spaces.
# 19. total_of_special_requests:
#
#   *   Most bookings have 0 or 1 special requests (mean of 0.572).
#   *   There are some bookings with up to 5 special requests.

# %%
data.drop('agent',axis=1, inplace = True)
Cols_Cat.remove('agent')

# %% [markdown]
# #### Object Features

# %%
data.describe(include=['object']).T
# Out:
#                        count unique                                top    freq
# hotel                 118991     64  Las Vegas Marriott Las Vegas, NV     1938
# arrival_date_month    118991     12                             August   13809
# meal                  118991      5                                 BB   91979
# country               118503    177                                PRT   48318
# market_segment        118991      8                          Online TA   56366
# distribution_channel  118991      5                              TA/TO   97514
# reserved_room_type    118991     10                                  A   85661
# assigned_room_type    118991     12                                  A   73752
# deposit_type          118991      3                         No Deposit  104266
# customer_type         118991      4                          Transient   89438
# reservation_status    118991      3                          Check-Out   75024

# %%
for i in data.describe(include=['object']).columns:
    print('Unique values in',i, 'are :')
    print(data[i].value_counts())
    print('*'*50)
# Out:
# Unique values in hotel are :
# Las Vegas Marriott Las Vegas, NV                                                             1938
# Protea Hotel by Marriott Midrand Midrand, South Africa                                       1932
# Sheraton Lima Hotel & Convention Center Lima, Peru                                           1929
# Sacramento Airport Natomas Courtyard Sacramento, CA                                          1927
# Waves, Barbados Barbados                                                                     1923
# Heidelberg Marriott Hotel Heidelberg, Germany                                                1920
# Renaissance New York Times Square Hotel New York, NY                                         1916
# Baton Rouge Acadian Centre/LSU Area Courtyard Baton Rouge, LA                                1916
# W London – Leicester Square London, United Kingdom                                           1909
# The Ritz-Carlton, Berlin Berlin, Germany                                                     1905
# Anaheim Marriott Anaheim, CA                                                                 1901
# Hotel Alfonso XIII, a Luxury Collection Hotel, Seville Seville, Spain                        1898
# Grosvenor House, A JW Marriott Hotel London, United Kingdom                                  1893
# Treasure Beach, Barbados Barbados                                                            1889
# W Barcelona Barcelona, Spain                                                                 1887
# Colony Club, Barbados Barbados                                                               1885
# Albuquerque Airport Courtyard Albuquerque, NM                                                1884
# Baltimore BWI Airport Courtyard Linthicum, MD                                                1883
# Courtyard by Marriott Toulouse Airport Toulouse, France                                      1882
# Hotel Maria Cristina, San Sebastian San Sebastian, Spain                                     1882
# Des Moines West/Clive Courtyard Clive, IA                                                    1882
# Courtyard by Marriott Paris Gare de Lyon Paris, France                                       1878
# Crystal Cove, Barbados Barbados                                                              1877
# Indianapolis Airport Courtyard Indianapolis, IN                                              1877
# Turtle Beach, Barbados Barbados                                                              1872
# The Ritz-Carlton, Tokyo Tokyo, Japan                                                         1871
# Orlando Airport Courtyard Orlando, FL                                                        1868
# Spokane Downtown at the Convention Center Courtyard Spokane, WA                              1868
# Residence Inn Las Vegas Convention Center Las Vegas, NV                                      1868
# Protea Hotel Fire & Ice! by Marriott Cape Town Cape Town, South Africa                       1866
# Chicago O'Hare Courtyard Des Plaines, IL                                                     1864
# Sheraton Diana Majestic, Milan Milan, Italy                                                  1863
# The St. Regis Osaka Osaka, Japan                                                             1861
# Berlin Marriott Hotel Berlin, Germany                                                        1859
# Protea Hotel by Marriott Cape Town Sea Point Cape Town, South Africa                         1859
# Leipzig Marriott Hotel Leipzig, Germany                                                      1859
# Orlando International Drive/Convention Center Courtyard Orlando, FL                          1855
# Fort Worth University Drive Courtyard Fort Worth, TX                                         1854
# Louisville East Courtyard Louisville, KY                                                     1852
# Renaissance Hamburg Hotel Hamburg, Germany                                                   1849
# Courtyard by Marriott Rio de Janeiro Barra da Tijuca Barra da Tijuca, Brazil                 1848
# Cape Town Marriott Hotel Crystal Towers Cape Town, South Africa                              1845
# The Westin Peachtree Plaza, Atlanta Atlanta, GA                                              1844
# Newark Liberty International Airport Courtyard Newark, NJ                                    1843
# Greensboro Courtyard Greensboro, NC                                                          1840
# Protea Hotel Fire & Ice! by Marriott Johannesburg Melrose Arch Johannesburg, South Africa    1839
# Tamarind, Barbados Barbados                                                                  1837
# Mt. Laurel Courtyard Mt. Laurel, NJ                                                          1835
# Marriott Puerto Vallarta Resort & Spa Puerto Vallarta, Mexico                                1833
# Irvine John Wayne Airport/Orange County Courtyard Irvine, CA                                 1830
# Frankfurt Marriott Hotel Frankfurt, Germany                                                  1830
# Sheraton Mexico City Maria Isabel Hotel Mexico City, Mexico                                  1825
# San Diego Sorrento Valley Courtyard San Diego, CA                                            1815
# African Pride Melrose Arch, Autograph Collection Johannesburg, South Africa                  1814
# The House, Barbados Barbados                                                                 1812
# W New York – Times Square New York, NY                                                       1809
# Courtyard Las Vegas Convention Center Las Vegas, NV                                          1807
# Renaissance Santo Domingo Jaragua Hotel & Casino Santo Domingo, Dominican Republic           1806
# Courtyard by Marriott Aberdeen Airport Aberdeen, United Kingdom                              1806
# Protea Hotel by Marriott O.R. Tambo Airport Johannesburg, South Africa                       1805
# Residence Inn Rio de Janeiro Barra da Tijuca Barra da Tijuca, Brazil                         1796
# W New York – Union Square New York, NY                                                       1763
# St. Louis Downtown West Courtyard St. Louis, MO                                              1758
# Sheraton Grand Rio Hotel & Resort Rio de Janeiro, Brazil                                     1750
# Name: hotel, dtype: int64
# **************************************************
# Unique values in arrival_date_month are :
# August       13809
# July         12537
# May          11787
# October      11160
# April        11078
# June         10934
# September    10486
# March         9771
# February      7926
# November      6794
# December      6780
# January       5929
# Name: arrival_date_month, dtype: int64
# **************************************************
# Unique values in meal are :
# BB           91979
# HB           14439
# SC           10638
# Undefined     1168
# FB             767
# Name: meal, dtype: int64
# **************************************************
# Unique values in country are :
# PRT    48318
# GBR    12116
# FRA    10407
# ESP     8496
# DEU     7279
# ITA     3762
# IRL     3372
# BEL     2340
# BRA     2220
# NLD     2100
# USA     2096
# CHE     1727
# CN      1279
# AUT     1262
# SWE     1024
# CHN      999
# POL      919
# ISR      669
# RUS      631
# NOR      607
# ROU      500
# FIN      447
# DNK      435
# AUS      426
# AGO      362
# LUX      287
# MAR      257
# TUR      248
# HUN      230
# ARG      214
# JPN      197
# CZE      171
# IND      152
# KOR      133
# GRC      128
# DZA      103
# SRB      101
# HRV      100
# MEX       85
# EST       83
# IRN       83
# LTU       81
# ZAF       80
# BGR       75
# NZL       74
# COL       71
# UKR       68
# MOZ       67
# CHL       65
# SVK       65
# THA       59
# SVN       57
# ISL       57
# LVA       55
# ARE       51
# CYP       51
# TWN       51
# SAU       48
# PHL       40
# TUN       39
# SGP       39
# IDN       35
# NGA       34
# EGY       32
# URY       32
# LBN       31
# PER       29
# HKG       29
# MYS       28
# ECU       27
# VEN       26
# BLR       26
# CPV       24
# GEO       22
# JOR       21
# KAZ       19
# CRI       19
# GIB       18
# MLT       18
# OMN       18
# AZE       17
# KWT       16
# MAC       16
# QAT       15
# IRQ       14
# DOM       14
# PAK       14
# BIH       13
# MDV       12
# BGD       12
# ALB       12
# PRI       12
# SEN       11
# CMR       10
# MKD       10
# BOL       10
# PAN        9
# GNB        9
# TJK        9
# VNM        8
# CUB        8
# ARM        8
# JEY        8
# LBY        8
# AND        7
# MUS        7
# LKA        7
# CIV        6
# KEN        6
# FRO        5
# MNE        5
# TZA        5
# BHR        5
# JAM        5
# CAF        5
# SUR        5
# PRY        4
# BRB        4
# GTM        4
# UZB        4
# MCO        4
# GAB        4
# GHA        4
# ZWE        4
# ETH        3
# TMP        3
# LIE        3
# GGY        3
# SYR        3
# BEN        3
# GLP        2
# SLV        2
# ATA        2
# MYT        2
# ABW        2
# KHM        2
# LAO        2
# STP        2
# ZMB        2
# MWI        2
# IMN        2
# COM        2
# TGO        2
# UGA        2
# KNA        2
# RWA        2
# SYC        2
# KIR        1
# SDN        1
# NCL        1
# AIA        1
# ASM        1
# FJI        1
# ATF        1
# LCA        1
# GUY        1
# PYF        1
# DMA        1
# SLE        1
# MRT        1
# NIC        1
# BDI        1
# PLW        1
# MLI        1
# CYM        1
# BFA        1
# MDG        1
# MMR        1
# NPL        1
# BHS        1
# UMI        1
# SMR        1
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: country, dtype: int64
# **************************************************
# Unique values in market_segment are :
# Online TA        56366
# Offline TA/TO    24183
# Groups           19582
# Direct           12587
# Corporate         5294
# Complementary      740
# Aviation           237
# Undefined            2
# Name: market_segment, dtype: int64
# **************************************************
# Unique values in distribution_channel are :
# TA/TO        97514
# Direct       14603
# Corporate     6676
# GDS            193
# Undefined        5
# Name: distribution_channel, dtype: int64
# **************************************************
# Unique values in reserved_room_type are :
# A    85661
# D    19160
# E     6524
# F     2894
# G     2088
# B     1118
# C      929
# H      599
# P       12
# L        6
# Name: reserved_room_type, dtype: int64
# **************************************************
# Unique values in assigned_room_type are :
# A    73752
# D    25267
# E     7787
# F     3746
# G     2546
# C     2365
# B     2163
# H      710
# I      363
# K      279
# P       12
# L        1
# Name: assigned_room_type, dtype: int64
# **************************************************
# Unique values in deposit_type are :
# No Deposit    104266
# Non Refund     14563
# Refundable       162
# Name: deposit_type, dtype: int64
# **************************************************
# Unique values in customer_type are :
# Transient          89438
# Transient-Party    24906
# Contract            4076
# Group                571
# Name: customer_type, dtype: int64
# **************************************************
# Unique values in reservation_status are :
# Check-Out    75024
# Canceled     42760
# No-Show       1207
# Name: reservation_status, dtype: int64
# **************************************************

# %% [markdown]
# #### **Observations**
# * Number of reservations per hotel are balanced
# * Most customers are transient
# * Most meals are BB.
# * Most customers are from Portugual.
# * The highest market segment is Online TA
# * The biggest distribution channel is TA/TO
# * Most Reserved Room Types are Type A
# * Most Assigned Room Types are Type A
# * Most customers don't give a deposit.
# * Most reservation's status are Check-Out
#
# **Missing values**
# * 'Unknown' value can be considered and treated as missing values.

# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS
# #### Univariate Analysis

# %%
def create_grid_of_plots(df, columns, figsize=(15, 5), bins=None):
  full_rows = math.floor(len(Cols_Num)/3)
  last_row_elems = len(Cols_Num) % 3
  for i in range(0,full_rows*3,3):
    pltcols = Cols_Num[i:i+3]
    fig, axes = plt.subplots(nrows = 2, ncols = 3, figsize=figsize, gridspec_kw={"height_ratios": (0.25, 0.75)})
    fig.subplots_adjust(hspace=0.18)
    for j in range(3):
      col = pltcols[j]
      ax = axes[0, j%3]
      ax2 = axes[1, j%3]
      feature = df[col]
      multi_histogram_boxplot(feature, ax, ax2, bins)
      ax.set_title(col).set_position([0.5, -3])
    plt.show()
  if (last_row_elems > 0):
    pltcols = Cols_Num[len(Cols_Num)-last_row_elems:]
    if len(pltcols) == 1:
      single_histogram_boxplot(df,pltcols[0])
    else:
      fig, axes = plt.subplots(nrows = 2, ncols = len(pltcols), figsize = (len(pltcols)*5, 5), gridspec_kw={"height_ratios": (0.25, 0.75)})
      print(axes)
      fig.subplots_adjust(hspace=0.15)
      for j in range(len(pltcols)):
        col = pltcols[j]
        ax = axes[0, j%len(pltcols)]
        ax2 = axes[1, j%len(pltcols)]
        feature = df[col]
        multi_histogram_boxplot(feature, ax, ax2, bins)
        ax.set_title(col).set_position([0.5, -3])
      plt.show()


def multi_histogram_boxplot(feature, ax, ax2, bins=None):
    sns.boxplot(feature, ax=ax, showmeans=True, color='violet', orient="h")
    if bins:
        sns.distplot(feature, kde=False, ax=ax2, bins=bins, color='tab:cyan')
    else:
        sns.distplot(feature, kde=False, ax=ax2, color='tab:cyan')
    ax2.set_xlabel('')
    ax2.axvline(np.mean(feature), color='purple', linestyle='--')
    ax2.axvline(np.median(feature), color='blue', linestyle='-')


def single_histogram_boxplot(df,col, figsize=(5,5), bins = None):
    feature = df[col]
    f2, (ax_box2, ax_hist2) = plt.subplots(nrows = 2, # Number of rows of the subplot grid= 2
                                           gridspec_kw = {"height_ratios": (.25, .75)},
                                           figsize = figsize
                                           ) # creating the 2 subplots
    ax_box2.set_title(col).set_position([0.5, -3])
    sns.boxplot(feature, ax=ax_box2, showmeans=True, color='violet', orient="h") # boxplot will be created and a star will indicate the mean value of the column
    sns.distplot(feature, kde=False, ax=ax_hist2, bins=bins,color = 'orange') if bins else sns.distplot(feature, kde=False, ax=ax_hist2,color='tab:cyan') # For histogram
    ax_hist2.axvline(np.mean(feature), color='purple', linestyle='--') # Add mean to the histogram
    ax_hist2.axvline(np.median(feature), color='black', linestyle='-') # Add median to the histogram

# %%
create_grid_of_plots(data, Cols_Num)

# %% [markdown]
# ### Observations
# - ADR, Required Parking Spaces and Children have a big separation between the values and the outliers. Also they are few samples. We can remove the outliers
# - All graphs show an important skew to the left
# - Most of the reservations are done with less than a 100 days of lead time
# - Most of the stays are during the weekends
# - Most of the users don't have any previous cancellations, nor booking changes
# - Most of the users didn't have to be in the waiting list
# - Most common ADR is less than $300
# - Most users dind't require parking spaces

# %%
CatCols_2Rev = ["meal", "market_segment", "distribution_channel", "reserved_room_type", "assigned_room_type","deposit_type","customer_type","reservation_status"]
def create_grid_of_perc_on_bar(df, columns, figsize=(30, 10)):
    num_cols = len(columns)
    num_rows = int(np.ceil(num_cols / 4))

    plt.figure(figsize=figsize)
    fig, axes = plt.subplots(nrows = num_rows, ncols=4, figsize=figsize)
    row = -1
    for i, col in enumerate(columns):
        if i%4==0:
          row+=1
        ax2 = axes[row,i%4]
        perc_on_bar(df, col, ax2)

    plt.tight_layout()  # Ensure proper spacing between subplots
    plt.show()


def perc_on_bar(df,z,ax2):
    '''
    plot
    feature: categorical feature
    the function won't work if a column is passed in hue parameter
    '''

    total = len(df[z]) # length of the column
    ax = sns.countplot(data= df, x = z,ax = ax2,palette='Paired')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total) # percentage of each class of the category
        x = p.get_x() + p.get_width() / 2 - 0.05 # width of the plot
        y = p.get_y() + p.get_height()           # hieght of the plot

        ax.annotate(percentage, (x, y), size = 10) # annotate the percantage

# %%
create_grid_of_perc_on_bar(data,CatCols_2Rev)

# %% [markdown]
# ### Observations:
# - Most requested meal type is BB
# - Biggest market segment is Online TA
# - Biggest distribution channel is TA/TO
# - Reserved rooms mostly match the assigned rooms
# - Most of the customers do not leave a deposit
# - Most customers are transient
# - Most reservations are fulfilled

# %% [markdown]
# ## Multivariate Analysis

# %%
plt.figure(figsize=(15,7))
sns.heatmap(data.corr(),annot=True,vmin=-1,vmax=1,fmt='.2f',cmap='Spectral')
plt.show()

# %% [markdown]
# ### Observations
# - There is a positive correlation between previous booking not cancelled and if the guest is a repeated guest
# - The more children, the highest the ADR
# - There is a positive correlation between stays in week nights and stays in weekend nights
# - The greatest the lead time, the less cancellations
# - THe more special requests, the less cancellations

# %%
def numcat_plot(x,target='is_canceled'):
    fig,axs = plt.subplots(2,2,figsize=(12,10))
    axs[0, 0].set_title('Distribution of Cancelled Reservations')
    sns.distplot(data[(data[target] == 1)][x],ax=axs[0,0],color='teal')
    axs[0, 1].set_title('Distribution of an Non Cancelled Reservations')
    sns.distplot(data[(data[target] == 0)][x],ax=axs[0,1],color='orange')
    axs[1,0].set_title('Boxplot w.r.t ' + target)
    sns.boxplot(data=data, x=target, y=x ,ax=axs[1,0],palette='gist_rainbow')
    axs[1,1].set_title(f'Boxplot w.r.t {target} - Without outliers')
    sns.boxplot(data=data, x=target, y=x,ax=axs[1,1],showfliers=False,palette='gist_rainbow')
    plt.tight_layout()
    plt.show()


numcat_plot("lead_time")

# %% [markdown]
# The cancelled reservations had a biggest lead time

# %%
numcat_plot("total_of_special_requests")

# %% [markdown]
# Non Cancelled Reservations had a highest number of special requests

# %%
numcat_plot("previous_bookings_not_canceled","is_repeated_guest")

# %% [markdown]
# repeated guests have a highest number of not cancelled bookings

# %%
sns.lineplot(data = data, x ='children', y = 'adr',hue='is_canceled',ci=0)
# Out:
# <Axes: xlabel='children', ylabel='adr'>

# %%
sns.lineplot(data = data, x ='adults', y = 'adr',hue='is_canceled',ci=0)
# Out:
# <Axes: xlabel='adults', ylabel='adr'>

# %%
data = data.drop(data[data["adr"] == 0].index)
data = data.drop(data[data["adr"] > 5000].index)

# %%
sns.lineplot(data = data, x ='lead_time', y = 'adr',hue='is_canceled',ci=0)
# Out:
# <Axes: xlabel='lead_time', ylabel='adr'>

# %%
def stacked_plot(x, target = "is_canceled"):
    sns.set()
    ## crosstab
    tab1 = pd.crosstab(data[x],data[target],margins=True).sort_values(by=1,ascending=False)
    print(tab1)
    print('-'*120)
    ## visualising the cross tab
    tab = pd.crosstab(data[x],data[target],normalize='index').sort_values(by=1,ascending=False)
    tab.plot(kind='bar',stacked=True,figsize=(25,7))
    plt.legend(loc='lower left', frameon=False,)
    plt.legend(loc="upper left", bbox_to_anchor=(1,1))
    plt.show()

# %%
stacked_plot("distribution_channel")
# Out:
# is_canceled               0      1     All
# distribution_channel
# All                   73280  43754  117034
# TA/TO                 56744  39814   96558
# Direct                11346   2452   13798
# Corporate              5037   1447    6484
# GDS                     152     37     189
# Undefined                 1      4       5
# ------------------------------------------------------------------------------------------------------------------------

# %%
stacked_plot("customer_type")
# Out:
# is_canceled          0      1     All
# customer_type
# All              73280  43754  117034
# Transient        51709  36280   87989
# Transient-Party  18284   6171   24455
# Contract          2791   1261    4052
# Group              496     42     538
# ------------------------------------------------------------------------------------------------------------------------

# %%
stacked_plot("meal")
# Out:
# is_canceled      0      1     All
# meal
# All          73280  43754  117034
# BB           56379  34106   90485
# HB            9278   4960   14238
# SC            6502   3927   10429
# FB             275    477     752
# Undefined      846    284    1130
# ------------------------------------------------------------------------------------------------------------------------

# %%
data.drop(['meal'], axis=1, inplace=True)

# %%
stacked_plot("country")
# Out:
# is_canceled      0      1     All
# country
# All          72870  43697  116567
# PRT          19674  27095   46769
# GBR           9594   2449   12043
# ESP           6242   2176    8418
# FRA           8422   1930   10352
# ITA           2416   1329    3745
# DEU           6022   1216    7238
# IRL           2534    832    3366
# BRA           1381    826    2207
# USA           1586    499    2085
# BEL           1861    471    2332
# CHN            535    462     997
# CHE           1295    426    1721
# NLD           1710    386    2096
# CN            1021    254    1275
# RUS            386    238     624
# AUT           1026    229    1255
# SWE            791    227    1018
# POL            696    213     909
# AGO            150    205     355
# NOR            425    181     606
# ISR            497    169     666
# ROU            366    134     500
# LUX            177    109     286
# DNK            325    109     434
# MAR            147    107     254
# AUS            319    107     426
# TUR            146    102     248
# HUN            151     77     228
# FIN            376     68     444
# KOR             78     55     133
# ARG            160     53     213
# ARE              7     43      50
# CZE            133     37     170
# IND            116     35     151
# GRC             93     35     128
# SAU             15     33      48
# ZAF             49     31      80
# JPN            169     28     197
# HKG              3     26      29
# HRV             75     25     100
# PHL             15     25      40
# SVK             41     24      65
# IDN             11     24      35
# IRN             60     23      83
# COL             48     23      71
# DZA             82     21     103
# NGA             13     21      34
# UKR             47     20      67
# MOZ             47     19      66
# TUN             19     19      38
# THA             41     18      59
# EST             65     18      83
# SGP             23     16      39
# CHL             49     16      65
# GEO              7     15      22
# MAC              1     15      16
# SVN             40     15      55
# TWN             37     14      51
# BGR             63     12      75
# VEN             14     12      26
# CPV             12     12      24
# QAT              3     11      14
# GIB              7     11      18
# EGY             21     11      32
# CYP             39     11      50
# MEX             74     10      84
# URY             23      9      32
# AZE              8      9      17
# MDV              3      9      12
# BGD              3      9      12
# PAK              5      9      14
# LVA             46      9      55
# LBN             22      9      31
# SEN              3      8      11
# JEY              0      8       8
# BLR             17      8      25
# ECU             19      8      27
# DOM              6      8      14
# TJK              1      8       9
# LTU             74      7      81
# PER             23      6      29
# NZL             68      6      74
# KWT             10      6      16
# MLT             13      5      18
# KAZ             14      5      19
# AND              2      5       7
# FRO              1      4       5
# BHR              1      4       5
# OMN             14      4      18
# ISL             52      4      56
# BEN              0      3       3
# JOR             18      3      21
# GGY              0      3       3
# TZA              1      3       4
# MYS             25      3      28
# BIH             10      3      13
# SRB             97      3     100
# UZB              2      2       4
# PRI             10      2      12
# CIV              4      2       6
# MYT              0      2       2
# ALB             10      2      12
# ZWE              2      2       4
# MNE              3      2       5
# MKD              8      2      10
# IMN              0      2       2
# VNM              6      2       8
# KEN              4      2       6
# KHM              0      2       2
# GLP              0      2       2
# ARM              6      2       8
# GHA              2      2       4
# GAB              2      2       4
# CRI             18      1      19
# HND              0      1       1
# GNB              8      1       9
# ZMB              1      1       2
# UMI              0      1       1
# SYC              1      1       2
# NIC              0      1       1
# TMP              2      1       3
# FJI              0      1       1
# MCO              3      1       4
# LIE              2      1       3
# ETH              2      1       3
# MUS              6      1       7
# VGB              0      1       1
# SYR              3      0       3
# SMR              1      0       1
# RWA              2      0       2
# SLV              2      0       2
# STP              2      0       2
# SLE              1      0       1
# SUR              5      0       5
# SDN              1      0       1
# UGA              2      0       2
# TGO              2      0       2
# ABW              2      0       2
# PYF              1      0       1
# BRB              4      0       4
# DJI              1      0       1
# CYM              1      0       1
# CUB              8      0       8
# COM              2      0       2
# CMR              9      0       9
# CAF              5      0       5
# BWA              1      0       1
# BOL              9      0       9
# GTM              4      0       4
# BHS              1      0       1
# BFA              1      0       1
# BDI              1      0       1
# ATF              1      0       1
# ATA              2      0       2
# ASM              1      0       1
# AIA              1      0       1
# DMA              1      0       1
# GUY              1      0       1
# PRY              4      0       4
# MMR              1      0       1
# PLW              1      0       1
# PAN              9      0       9
# NPL              1      0       1
# NCL              1      0       1
# NAM              1      0       1
# MWI              2      0       2
# MRT              1      0       1
# MLI              1      0       1
# IRQ             14      0      14
# MDG              1      0       1
# LKA              7      0       7
# LCA              1      0       1
# LBY              8      0       8
# LAO              2      0       2
# KNA              2      0       2
# JAM              5      0       5
# KIR              1      0       1
# ------------------------------------------------------------------------------------------------------------------------

# %%
ax =sns.countplot(data=data, x='arrival_date_month', hue='is_canceled')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'July'),
#  Text(1, 0, 'August'),
#  Text(2, 0, 'September'),
#  Text(3, 0, 'October'),
#  Text(4, 0, 'November'),
#  Text(5, 0, 'December'),
#  Text(6, 0, 'January'),
#  Text(7, 0, 'February'),
#  Text(8, 0, 'March'),
#  Text(9, 0, 'April'),
#  Text(10, 0, 'May'),
#  Text(11, 0, 'June')]

# %%
ax = sns.countplot(data=data, x='arrival_date_year', hue='is_canceled')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, '2017'), Text(1, 0, '2018'), Text(2, 0, '2019')]

# %%
sns.histplot(data=data['children'])
# Out:
# <Axes: xlabel='children', ylabel='Count'>

# %%
sns.histplot(data=data['babies'])
# Out:
# <Axes: xlabel='babies', ylabel='Count'>

# %%
((len(data.loc[(data['children']!=0) | (data['babies']!=0)]))/(len(data))) * 100
# Out:
# 7.866944648563664

# %%
sns.histplot(data=data['is_canceled'])
# Out:
# <Axes: xlabel='is_canceled', ylabel='Count'>

# %% [markdown]
# ## FEATURE ENGINEERING

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117034 entries, 2 to 118990
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           117034 non-null  object
#  1   is_canceled                     117034 non-null  int64
#  2   lead_time                       117034 non-null  int64
#  3   arrival_date_year               117034 non-null  int64
#  4   arrival_date_month              117034 non-null  object
#  5   arrival_date_week_number        117034 non-null  int64
#  6   arrival_date_day_of_month       117034 non-null  int64
#  7   stays_in_weekend_nights         117034 non-null  int64
#  8   stays_in_week_nights            117034 non-null  int64
#  9   adults                          117034 non-null  int64
#  10  children                        117030 non-null  float64
#  11  babies                          117034 non-null  int64
#  12  country                         116567 non-null  object
#  13  market_segment                  117034 non-null  object
#  14  distribution_channel            117034 non-null  object
#  15  is_repeated_guest               117034 non-null  int64
#  16  previous_cancellations          117034 non-null  int64
#  17  previous_bookings_not_canceled  117034 non-null  int64
#  18  reserved_room_type              117034 non-null  object
#  19  assigned_room_type              117034 non-null  object
#  20  booking_changes                 117034 non-null  int64
#  21  deposit_type                    117034 non-null  object
#  22  days_in_waiting_list            117034 non-null  int64
#  23  customer_type                   117034 non-null  object
#  24  adr                             117034 non-null  float64
#  25  required_car_parking_spaces     117034 non-null  int64
#  26  total_of_special_requests       117034 non-null  int64
#  27  reservation_status              117034 non-null  object
#  28  reservation_status_date         117034 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(16), object(10)
# memory usage: 26.8+ MB

# %% [markdown]
# ### Total Guests + Children

# %%
data['children'].fillna(0, inplace=True)
data['babies'].fillna(0, inplace=True)
data['Total_Guests'] = data['children'] + data['babies'] + data['adults']

# %%
def Bring_Children(row):
    if (row['children'] + row['babies']) < 1:
        return False
    else:
        return True

data['Bring_Children'] = data.apply(Bring_Children, axis=1)

# %%
data.drop(['children', 'babies', 'adults'], axis=1, inplace=True)

# %% [markdown]
# ### Arrival Date Column Combination + Stay Duration Column

# %%
dicMonth = {'January':'01', 'February':'02', 'March':'03', 'April':'04', 'May':'05', 'June':'06', 'July':'07', 'August':'08', 'September':'09', 'October':'10', 'November':'11', 'December':'12'}
data.arrival_date_month = data.arrival_date_month.map(dicMonth).astype(int)

# %%
data['arrival_date'] = data['arrival_date_year'].astype(str)+'-'+data['arrival_date_month'].astype(str)+'-'+data['arrival_date_day_of_month'].astype(str)
data['arrival_date'] = data['arrival_date'].replace("2018-2-29", "2018-3-1")
data['arrival_date'] = pd.to_datetime(data['arrival_date'])

# %%
data['arrival_date_weekday'] = data['arrival_date'].dt.dayofweek

# %%
data['stay_duration'] = data['stays_in_weekend_nights'] + data['stays_in_week_nights']

# %%
data.drop(['arrival_date_year', 'arrival_date_month', 'arrival_date_day_of_month', 'reservation_status_date','reservation_status', 'arrival_date'], axis=1, inplace=True)

# %% [markdown]
# ### Room Change

# %%
def roomChange(row):
    if row['assigned_room_type'] == row['reserved_room_type']:
        return False
    else:
        return True

data['change_in_room'] = data.apply(roomChange, axis=1)

# %%
data.drop(['assigned_room_type', 'reserved_room_type'], axis=1, inplace=True)

# %% [markdown]
# ### Generate Missing Countries

# %%
import pycountry

def generate_country_code(row):
    hotel_info = row['hotel'].split(',')
    last_element = hotel_info[-1].strip()
    if len(last_element) == 2:
        return 'USA'
    elif "Barbados" in last_element:
      return "BRB"
    else:
        try:
            country = pycountry.countries.get(name=last_element)
            if country:
                return country.alpha_3
        except LookupError:
            print(last_element)
    return None

# %%
data['country'] = data.apply(generate_country_code, axis=1)

# %% [markdown]
# ### Repeated Guest

# %%
def prev_cancellation_perc(row):
    if row['previous_cancellations']+row['previous_bookings_not_canceled'] == 0:
        return 0
    else:
        return row['previous_cancellations']/(row['previous_cancellations']+row['previous_bookings_not_canceled'])

data['cancellation_percentage'] = data.apply(prev_cancellation_perc, axis=1)

# %%
data.drop(['previous_cancellations', 'previous_bookings_not_canceled','is_repeated_guest'], axis=1, inplace=True)

# %% [markdown]
# ### Dataset After Cleaning

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117034 entries, 2 to 118990
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   hotel                        117034 non-null  object
#  1   is_canceled                  117034 non-null  int64
#  2   lead_time                    117034 non-null  int64
#  3   arrival_date_week_number     117034 non-null  int64
#  4   stays_in_weekend_nights      117034 non-null  int64
#  5   stays_in_week_nights         117034 non-null  int64
#  6   country                      117034 non-null  object
#  7   market_segment               117034 non-null  object
#  8   distribution_channel         117034 non-null  object
#  9   booking_changes              117034 non-null  int64
#  10  deposit_type                 117034 non-null  object
#  11  days_in_waiting_list         117034 non-null  int64
#  12  customer_type                117034 non-null  object
#  13  adr                          117034 non-null  float64
#  14  required_car_parking_spaces  117034 non-null  int64
#  15  total_of_special_requests    117034 non-null  int64
#  16  Total_Guests                 117034 non-null  float64
#  17  Bring_Children               117034 non-null  bool
#  18  arrival_date_weekday         117034 non-null  int64
#  19  stay_duration                117034 non-null  int64
#  20  change_in_room               117034 non-null  bool
#  21  cancellation_percentage      117034 non-null  float64
# dtypes: bool(2), float64(3), int64(11), object(6)
# memory usage: 19.0+ MB

# %%
data.to_csv('/content/drive/MyDrive/Maestria/6 Trimestre/Equipo_1/Proyecto Integrador/JWM_Clean_DataSet.csv',index=False)

# %% [markdown]
# ### One-Hot Enconding

# %%
df = data.copy()

# %%
from sklearn.preprocessing import OneHotEncoder

# Create a OneHotEncoder object
onehot_encoder = OneHotEncoder(sparse=False,handle_unknown='ignore')

# Fit and transform the categorical column
encoded_columns = onehot_encoder.fit_transform(df[['hotel','country','market_segment','distribution_channel','deposit_type','customer_type']])

# %%
# Create a DataFrame from the encoded columns
data_encoded = pd.DataFrame(encoded_columns, columns=onehot_encoder.get_feature_names_out(['hotel','country','market_segment','distribution_channel','deposit_type','customer_type']))
data_encoded = data_encoded.reset_index(drop=True)
data_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117034 entries, 0 to 117033
# Data columns (total 97 columns):
#  #   Column                                                                                           Non-Null Count   Dtype
# ---  ------                                                                                           --------------   -----
#  0   hotel_African Pride Melrose Arch, Autograph Collection Johannesburg, South Africa                117034 non-null  float64
#  1   hotel_Albuquerque Airport Courtyard Albuquerque, NM                                              117034 non-null  float64
#  2   hotel_Anaheim Marriott Anaheim, CA                                                               117034 non-null  float64
#  3   hotel_Baltimore BWI Airport Courtyard Linthicum, MD                                              117034 non-null  float64
#  4   hotel_Baton Rouge Acadian Centre/LSU Area Courtyard Baton Rouge, LA                              117034 non-null  float64
#  5   hotel_Berlin Marriott Hotel Berlin, Germany                                                      117034 non-null  float64
#  6   hotel_Cape Town Marriott Hotel Crystal Towers Cape Town, South Africa                            117034 non-null  float64
#  7   hotel_Chicago O'Hare Courtyard Des Plaines, IL                                                   117034 non-null  float64
#  8   hotel_Colony Club, Barbados Barbados                                                             117034 non-null  float64
#  9   hotel_Courtyard Las Vegas Convention Center Las Vegas, NV                                        117034 non-null  float64
#  10  hotel_Courtyard by Marriott Aberdeen Airport Aberdeen, United Kingdom                            117034 non-null  float64
#  11  hotel_Courtyard by Marriott Paris Gare de Lyon Paris, France                                     117034 non-null  float64
#  12  hotel_Courtyard by Marriott Rio de Janeiro Barra da Tijuca Barra da Tijuca, Brazil               117034 non-null  float64
#  13  hotel_Courtyard by Marriott Toulouse Airport Toulouse, France                                    117034 non-null  float64
#  14  hotel_Crystal Cove, Barbados Barbados                                                            117034 non-null  float64
#  15  hotel_Des Moines West/Clive Courtyard Clive, IA                                                  117034 non-null  float64
#  16  hotel_Fort Worth University Drive Courtyard Fort Worth, TX                                       117034 non-null  float64
#  17  hotel_Frankfurt Marriott Hotel Frankfurt, Germany                                                117034 non-null  float64
#  18  hotel_Greensboro Courtyard Greensboro, NC                                                        117034 non-null  float64
#  19  hotel_Grosvenor House, A JW Marriott Hotel London, United Kingdom                                117034 non-null  float64
#  20  hotel_Heidelberg Marriott Hotel Heidelberg, Germany                                              117034 non-null  float64
#  21  hotel_Hotel Alfonso XIII, a Luxury Collection Hotel, Seville Seville, Spain                      117034 non-null  float64
#  22  hotel_Hotel Maria Cristina, San Sebastian San Sebastian, Spain                                   117034 non-null  float64
#  23  hotel_Indianapolis Airport Courtyard Indianapolis, IN                                            117034 non-null  float64
#  24  hotel_Irvine John Wayne Airport/Orange County Courtyard Irvine, CA                               117034 non-null  float64
#  25  hotel_Las Vegas Marriott Las Vegas, NV                                                           117034 non-null  float64
#  26  hotel_Leipzig Marriott Hotel Leipzig, Germany                                                    117034 non-null  float64
#  27  hotel_Louisville East Courtyard Louisville, KY                                                   117034 non-null  float64
#  28  hotel_Marriott Puerto Vallarta Resort & Spa Puerto Vallarta, Mexico                              117034 non-null  float64
#  29  hotel_Mt. Laurel Courtyard Mt. Laurel, NJ                                                        117034 non-null  float64
#  30  hotel_Newark Liberty International Airport Courtyard Newark, NJ                                  117034 non-null  float64
#  31  hotel_Orlando Airport Courtyard Orlando, FL                                                      117034 non-null  float64
#  32  hotel_Orlando International Drive/Convention Center Courtyard Orlando, FL                        117034 non-null  float64
#  33  hotel_Protea Hotel Fire & Ice! by Marriott Cape Town Cape Town, South Africa                     117034 non-null  float64
#  34  hotel_Protea Hotel Fire & Ice! by Marriott Johannesburg Melrose Arch Johannesburg, South Africa  117034 non-null  float64
#  35  hotel_Protea Hotel by Marriott Cape Town Sea Point Cape Town, South Africa                       117034 non-null  float64
#  36  hotel_Protea Hotel by Marriott Midrand Midrand, South Africa                                     117034 non-null  float64
#  37  hotel_Protea Hotel by Marriott O.R. Tambo Airport Johannesburg, South Africa                     117034 non-null  float64
#  38  hotel_Renaissance Hamburg Hotel Hamburg, Germany                                                 117034 non-null  float64
#  39  hotel_Renaissance New York Times Square Hotel New York, NY                                       117034 non-null  float64
#  40  hotel_Renaissance Santo Domingo Jaragua Hotel & Casino Santo Domingo, Dominican Republic         117034 non-null  float64
#  41  hotel_Residence Inn Las Vegas Convention Center Las Vegas, NV                                    117034 non-null  float64
#  42  hotel_Residence Inn Rio de Janeiro Barra da Tijuca Barra da Tijuca, Brazil                       117034 non-null  float64
#  43  hotel_Sacramento Airport Natomas Courtyard Sacramento, CA                                        117034 non-null  float64
#  44  hotel_San Diego Sorrento Valley Courtyard San Diego, CA                                          117034 non-null  float64
#  45  hotel_Sheraton Diana Majestic, Milan Milan, Italy                                                117034 non-null  float64
#  46  hotel_Sheraton Grand Rio Hotel & Resort Rio de Janeiro, Brazil                                   117034 non-null  float64
#  47  hotel_Sheraton Lima Hotel & Convention Center Lima, Peru                                         117034 non-null  float64
#  48  hotel_Sheraton Mexico City Maria Isabel Hotel Mexico City, Mexico                                117034 non-null  float64
#  49  hotel_Spokane Downtown at the Convention Center Courtyard Spokane, WA                            117034 non-null  float64
#  50  hotel_St. Louis Downtown West Courtyard St. Louis, MO                                            117034 non-null  float64
#  51  hotel_Tamarind, Barbados Barbados                                                                117034 non-null  float64
#  52  hotel_The House, Barbados Barbados                                                               117034 non-null  float64
#  53  hotel_The Ritz-Carlton, Berlin Berlin, Germany                                                   117034 non-null  float64
#  54  hotel_The Ritz-Carlton, Tokyo Tokyo, Japan                                                       117034 non-null  float64
#  55  hotel_The St. Regis Osaka Osaka, Japan                                                           117034 non-null  float64
#  56  hotel_The Westin Peachtree Plaza, Atlanta Atlanta, GA                                            117034 non-null  float64
#  57  hotel_Treasure Beach, Barbados Barbados                                                          117034 non-null  float64
#  58  hotel_Turtle Beach, Barbados Barbados                                                            117034 non-null  float64
#  59  hotel_W Barcelona Barcelona, Spain                                                               117034 non-null  float64
#  60  hotel_W London – Leicester Square London, United Kingdom                                         117034 non-null  float64
#  61  hotel_W New York – Times Square New York, NY                                                     117034 non-null  float64
#  62  hotel_W New York – Union Square New York, NY                                                     117034 non-null  float64
#  63  hotel_Waves, Barbados Barbados                                                                   117034 non-null  float64
#  64  country_BRA                                                                                      117034 non-null  float64
#  65  country_BRB                                                                                      117034 non-null  float64
#  66  country_DEU                                                                                      117034 non-null  float64
#  67  country_DOM                                                                                      117034 non-null  float64
#  68  country_ESP                                                                                      117034 non-null  float64
#  69  country_FRA                                                                                      117034 non-null  float64
#  70  country_GBR                                                                                      117034 non-null  float64
#  71  country_ITA                                                                                      117034 non-null  float64
#  72  country_JPN                                                                                      117034 non-null  float64
#  73  country_MEX                                                                                      117034 non-null  float64
#  74  country_PER                                                                                      117034 non-null  float64
#  75  country_USA                                                                                      117034 non-null  float64
#  76  country_ZAF                                                                                      117034 non-null  float64
#  77  market_segment_Aviation                                                                          117034 non-null  float64
#  78  market_segment_Complementary                                                                     117034 non-null  float64
#  79  market_segment_Corporate                                                                         117034 non-null  float64
#  80  market_segment_Direct                                                                            117034 non-null  float64
#  81  market_segment_Groups                                                                            117034 non-null  float64
#  82  market_segment_Offline TA/TO                                                                     117034 non-null  float64
#  83  market_segment_Online TA                                                                         117034 non-null  float64
#  84  market_segment_Undefined                                                                         117034 non-null  float64
#  85  distribution_channel_Corporate                                                                   117034 non-null  float64
#  86  distribution_channel_Direct                                                                      117034 non-null  float64
#  87  distribution_channel_GDS                                                                         117034 non-null  float64
#  88  distribution_channel_TA/TO                                                                       117034 non-null  float64
#  89  distribution_channel_Undefined                                                                   117034 non-null  float64
#  90  deposit_type_No Deposit                                                                          117034 non-null  float64
#  91  deposit_type_Non Refund                                                                          117034 non-null  float64
#  92  deposit_type_Refundable                                                                          117034 non-null  float64
#  93  customer_type_Contract                                                                           117034 non-null  float64
#  94  customer_type_Group                                                                              117034 non-null  float64
#  95  customer_type_Transient                                                                          117034 non-null  float64
#  96  customer_type_Transient-Party                                                                    117034 non-null  float64
# dtypes: float64(97)
# memory usage: 86.6 MB

# %%
df.drop(['hotel','country','market_segment','distribution_channel','deposit_type','customer_type'], axis=1, inplace=True)
df = df.reset_index(drop=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117034 entries, 0 to 117033
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   is_canceled                  117034 non-null  int64
#  1   lead_time                    117034 non-null  int64
#  2   arrival_date_week_number     117034 non-null  int64
#  3   stays_in_weekend_nights      117034 non-null  int64
#  4   stays_in_week_nights         117034 non-null  int64
#  5   booking_changes              117034 non-null  int64
#  6   days_in_waiting_list         117034 non-null  int64
#  7   adr                          117034 non-null  float64
#  8   required_car_parking_spaces  117034 non-null  int64
#  9   total_of_special_requests    117034 non-null  int64
#  10  Total_Guests                 117034 non-null  float64
#  11  Bring_Children               117034 non-null  bool
#  12  arrival_date_weekday         117034 non-null  int64
#  13  stay_duration                117034 non-null  int64
#  14  change_in_room               117034 non-null  bool
#  15  cancellation_percentage      117034 non-null  float64
# dtypes: bool(2), float64(3), int64(11)
# memory usage: 12.7 MB

# %%
df_preprocessed = pd.concat([df, data_encoded], axis=1)
df_preprocessed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117034 entries, 0 to 117033
# Columns: 113 entries, is_canceled to customer_type_Transient-Party
# dtypes: bool(2), float64(100), int64(11)
# memory usage: 99.3 MB

# %% [markdown]
# ## Model Generation

# %%
train_var = df_preprocessed.drop(['is_canceled'], axis=1)
test_var = df_preprocessed['is_canceled']
X_train, X_test, y_train, y_test = train_test_split(train_var, test_var, test_size=0.20)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((93627, 112), (93627,), (23407, 112), (23407,))

# %%
#Data scaling
std_scaler = StandardScaler()
std_scaler.fit(X_train)
X_train_std = std_scaler.transform(X_train)
X_test_std = std_scaler.transform(X_test)

# %%
def get_metrics_score(model,train,test,train_y,test_y,flag=True):
    '''
    model : classifier to predict values of X

    '''
    # defining an empty list to store train and test results
    score_list=[]

    pred_train = model.predict(train)
    pred_test = model.predict(test)

    train_acc = model.score(train,train_y)
    test_acc = model.score(test,test_y)

    train_recall = metrics.recall_score(train_y,pred_train)
    test_recall = metrics.recall_score(test_y,pred_test)

    train_precision = metrics.precision_score(train_y,pred_train)
    test_precision = metrics.precision_score(test_y,pred_test)

    score_list.extend((train_acc,test_acc,train_recall,test_recall,train_precision,test_precision))

    # If the flag is set to True then only the following print statements will be dispayed. The default value is set to True.
    if flag == True:
        print("Accuracy on training set : ",model.score(train,train_y))
        print("Accuracy on test set : ",model.score(test,test_y))
        print("Recall on training set : ",metrics.recall_score(train_y,pred_train))
        print("Recall on test set : ",metrics.recall_score(test_y,pred_test))
        print("Precision on training set : ",metrics.precision_score(train_y,pred_train))
        print("Precision on test set : ",metrics.precision_score(test_y,pred_test))

    return score_list # returning the list with train and test scores

# %%
def make_confusion_matrix(model,X_test_,y_actual_,labels=[1, 0]):
    '''
    model : classifier to predict values of X
    y_actual : ground truth

    '''
    y_predict = model.predict(X_test_)
    cm=metrics.confusion_matrix( y_actual_, y_predict, labels=[0, 1])
    df_cm = pd.DataFrame(cm, index = [i for i in ["Actual - Not Cancelled","Actual - Cancelled"]],
                  columns = [i for i in ['Predicted - Not Cancelled','Predicted - Cancelled']])
    group_counts = ["{0:0.0f}".format(value) for value in
                cm.flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in
                         cm.flatten()/np.sum(cm)]
    labels = [f"{v1}\n{v2}" for v1, v2 in
              zip(group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    plt.figure(figsize = (10,7))
    sns.heatmap(df_cm, annot=labels,fmt='')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# ### Logistic Regression

# %%
lr = LogisticRegression(random_state=1)
lr.fit(X_train_std,y_train)
# Out:
# LogisticRegression(random_state=1)

# %% [markdown]
# **Let's evaluate the model performance by using KFold and cross_val_score**
#
# - `K-Folds cross-validator` provides dataset indices to split data into train/validation sets. Split dataset into k consecutive stratified folds (without shuffling by default). Each fold is then used once as validation while the k - 1 remaining folds form the training set.

# %%
scoring='recall'
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=1)     #Setting number of splits equal to 5
cv_result_bfr=cross_val_score(estimator=lr, X=X_train_std, y=y_train, scoring=scoring, cv=kfold)
#Plotting boxplots for CV scores of model defined above
plt.boxplot(cv_result_bfr)
plt.show()

# %%
#Calculating different metrics
scores_LR = get_metrics_score(lr,X_train_std,X_test_std,y_train,y_test)

# creating confusion matrix
make_confusion_matrix(lr,X_test_std,y_test)
# Out:
# Accuracy on training set :  0.8123938607452978
# Accuracy on test set :  0.8146708249668903
# Recall on training set :  0.6212467829568201
# Recall on test set :  0.629212204007286
# Precision on training set :  0.8341332309464389
# Precision on test set :  0.836410411622276

# %% [markdown]
# ### Random Forest

# %%
rf = RandomForestClassifier(random_state=1)
rf.fit(X_train_std,y_train)
# Out:
# RandomForestClassifier(random_state=1)

# %%
scoring='recall'
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=1)     #Setting number of splits equal to 5
cv_result_bfr=cross_val_score(estimator=rf, X=X_train_std, y=y_train, scoring=scoring, cv=kfold)
#Plotting boxplots for CV scores of model defined above
plt.boxplot(cv_result_bfr)
plt.show()

# %%
#Calculating different metrics
scores_RF = get_metrics_score(rf,X_train_std,X_test_std,y_train,y_test)

# creating confusion matrix
make_confusion_matrix(rf,X_test_std,y_test)
# Out:
# Accuracy on training set :  0.9989319320281542
# Accuracy on test set :  0.852394582817106
# Recall on training set :  0.9982556476980269
# Recall on test set :  0.7214253187613844
# Precision on training set :  0.9988840563122353
# Precision on test set :  0.8627637848876787

# %% [markdown]
# ## Gradient Boosting Classifier

# %%
gbc = GradientBoostingClassifier(random_state=1)
gbc.fit(X_train_std,y_train)
# Out:
# GradientBoostingClassifier(random_state=1)

# %%
scoring='recall'
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=1)     #Setting number of splits equal to 5
cv_result_bfr=cross_val_score(estimator=gbc, X=X_train_std, y=y_train, scoring=scoring, cv=kfold)
#Plotting boxplots for CV scores of model defined above
plt.boxplot(cv_result_bfr)
plt.show()

# %%
#Calculating different metrics
scores_gbc = get_metrics_score(gbc,X_train_std,X_test_std,y_train,y_test)

# creating confusion matrix
make_confusion_matrix(gbc,X_test_std,y_test)
# Out:
# Accuracy on training set :  0.8197848911104703
# Accuracy on test set :  0.8233434442688085
# Recall on training set :  0.6225621961681441
# Recall on test set :  0.6328551912568307
# Precision on training set :  0.8556101395166045
# Precision on test set :  0.859329108053795

# %%
models = []  # Empty list to store all the models

# Appending pipelines for each model into the list
models.append(
    (
        "LR",
        Pipeline(
            steps=[
                ("log_reg", LogisticRegression(random_state=1)),
            ]
        ),
    )
)
models.append(
    (
        "RF",
        Pipeline(
            steps=[
                ("random_forest", RandomForestClassifier(random_state=1)),
            ]
        ),
    )
)
models.append(
    (
        "GBC",
        Pipeline(
            steps=[
                ("gradient_boosting", GradientBoostingClassifier(random_state=1)),
            ]
        ),
    )
)

results = []  # Empty list to store all model's CV scores
names = []  # Empty list to store name of the models

# loop through all models to get the mean cross validated score
for name, model in models:
    scoring = "recall"
    kfold = StratifiedKFold(
        n_splits=5, shuffle=True, random_state=1
    )  # Setting number of splits equal to 5
    cv_result = cross_val_score(estimator=model, X=X_train_std, y=y_train, scoring=scoring, cv=kfold)
    results.append(cv_result)
    names.append(name)
    print("{}: {}".format(name, cv_result.mean() * 100))
# Out:
# LR: 62.058907635115816
# RF: 70.61481269659708
# GBC: 62.24764083500144

# %%
# Plotting boxplots for CV scores of all models defined above
fig = plt.figure(figsize=(10, 7))

fig.suptitle("Algorithm Comparison")
ax = fig.add_subplot(111)

plt.boxplot(results)
ax.set_xticklabels(names)

plt.show()

# %% [markdown]
# - Random Forest presented the highest cross validated recall
# - Let's tune the models see if the performance improves

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# ### Tuned Logistic Regression

# %%
from scipy.stats import loguniform
lr_tuned = LogisticRegression(random_state=1)
lr_tuned_param_dist = {
        'penalty': ['l1', 'l2'],
        'C': loguniform(1e-3, 1e3),
        'solver': ['liblinear', 'saga'],
        'max_iter': [100, 300, 500]
    }

scorer = metrics.make_scorer(metrics.recall_score)

# Create the RandomizedSearchCV object
LR_Tuned_RandSearch = RandomizedSearchCV(
    lr_tuned,
    param_distributions=lr_tuned_param_dist,
    n_iter=10,
    cv=5,  # 5-fold cross-validation
    scoring=scorer,
    random_state=42,
    n_jobs=-1  # Use all available CPU cores
)

# Fit the model to the data
LR_Tuned_RandSearch.fit(X_train_std,y_train)

# Get the best hyperparameters
print("Best parameters are {} with CV score={}:" .format(LR_Tuned_RandSearch.best_params_,LR_Tuned_RandSearch.best_score_))
# Out:
# Best parameters are {'C': 4.676478725076045, 'max_iter': 100, 'penalty': 'l2', 'solver': 'liblinear'} with CV score=0.6198455819273663:

# %%
lr_hypertuned = LogisticRegression(**LR_Tuned_RandSearch.best_params_)
lr_hypertuned.fit(X_train_std,y_train)
#Calculating different metrics
scores_LRHype = get_metrics_score(lr_hypertuned,X_train_std,X_test_std,y_train,y_test)

# creating confusion matrix
make_confusion_matrix(lr_hypertuned,X_test_std,y_test)
# Out:
# Accuracy on training set :  0.8123831800655794
# Accuracy on test set :  0.8146708249668903
# Recall on training set :  0.6212753788961968
# Recall on test set :  0.629212204007286
# Precision on training set :  0.8340755528255528
# Precision on test set :  0.836410411622276

# %% [markdown]
# ## Tuning Random Forest

# %%
rf_tuned = RandomForestClassifier(random_state=1)
rf_param_dist = {
    "n_estimators": [100,150,250],
    "min_samples_leaf": np.arange(1, 10),
    "max_features": [np.arange(0.3, 0.6, 0.1),'sqrt','log2'],
    "max_samples": np.arange(0.2, 0.6, 0.1),
}
# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.recall_score)

# Create the RandomizedSearchCV object
RF_Tuned_RandSearch = RandomizedSearchCV(
    rf_tuned,
    param_distributions=rf_param_dist,
    n_iter=15,
    cv=5,  # 5-fold cross-validation
    scoring=scorer,
    random_state=42,
    n_jobs=-1  # Use all available CPU cores
)

# Fit the model to the data
RF_Tuned_RandSearch.fit(X_train_std,y_train)

# Get the best hyperparameters
print("Best parameters are {} with CV score={}:" .format(RF_Tuned_RandSearch.best_params_,RF_Tuned_RandSearch.best_score_))
# Out:
# Best parameters are {'n_estimators': 250, 'min_samples_leaf': 1, 'max_samples': 0.4000000000000001, 'max_features': 'sqrt'} with CV score=0.6916213897626537:

# %%
rf_hypertuned = RandomForestClassifier(**RF_Tuned_RandSearch.best_params_)
rf_hypertuned.fit(X_train_std,y_train)
#Calculating different metrics
scores_RFHype = get_metrics_score(rf_hypertuned,X_train_std,X_test_std,y_train,y_test)

# creating confusion matrix
make_confusion_matrix(rf_hypertuned,X_test_std,y_test)
# Out:
# Accuracy on training set :  0.953378833028934
# Accuracy on test set :  0.8480796342974324
# Recall on training set :  0.8933943380040035
# Recall on test set :  0.7075364298724954
# Precision on training set :  0.9800181937952884
# Precision on test set :  0.86295473479589

# %% [markdown]
# # Tuning GBC

# %%
gbc_tuned = GradientBoostingClassifier(random_state=1)
gbc_param_dist = {
    "n_estimators": np.arange(75, 150, 25),
    "learning_rate": [0.1, 0.01, 0.5, 1],
    "subsample": [0.5, 0.7, 1],
    "max_features": [0.5, 0.7, 1],
}
# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.recall_score)

# Create the RandomizedSearchCV object
GBC_Tuned_RandSearch = RandomizedSearchCV(
    gbc_tuned,
    param_distributions=gbc_param_dist,
    n_iter=10,
    cv=5,  # 5-fold cross-validation
    scoring=scorer,
    random_state=42,
    n_jobs=-1  # Use all available CPU cores
)

# Fit the model to the data
GBC_Tuned_RandSearch.fit(X_train_std,y_train)

# Get the best hyperparameters
print("Best parameters are {} with CV score={}:" .format(GBC_Tuned_RandSearch.best_params_,GBC_Tuned_RandSearch.best_score_))
# Out:
# Best parameters are {'subsample': 1, 'n_estimators': 100, 'max_features': 0.7, 'learning_rate': 1} with CV score=0.6905347440663425:

# %%
gbc_hypertuned = GradientBoostingClassifier(**GBC_Tuned_RandSearch.best_params_)
gbc_hypertuned.fit(X_train_std,y_train)
#Calculating different metrics
scores_GBCHype = get_metrics_score(gbc_hypertuned,X_train_std,X_test_std,y_train,y_test)

# creating confusion matrix
make_confusion_matrix(gbc_hypertuned,X_test_std,y_test)
# Out:
# Accuracy on training set :  0.8408899142341418
# Accuracy on test set :  0.8345366770624172
# Recall on training set :  0.7069488132685159
# Recall on test set :  0.7021857923497268
# Precision on training set :  0.8417146164584114
# Precision on test set :  0.8307070707070707

# %% [markdown]
# ## Model Comparison

# %%
# defining list of model
models = [lr,lr_hypertuned,rf,rf_hypertuned,gbc,gbc_hypertuned]

# defining empty lists to add train and test results
acc_train = []
acc_test = []
recall_train = []
recall_test = []
precision_train = []
precision_test = []

# looping through all the models to get the metrics score - Accuracy, Recall and Precision
for model in models:

    j = get_metrics_score(model,X_train_std,X_test_std,y_train,y_test,False)
    acc_train.append(j[0])
    acc_test.append(j[1])
    recall_train.append(j[2])
    recall_test.append(j[3])
    precision_train.append(j[4])
    precision_test.append(j[5])

# %%
comparison_frame = pd.DataFrame(
    {
        "Model": [
            "Logistic Regression",
            'Logistic Regression Hypertuned',
            "Random Forest",
            "Random Forest Hypertuned",
            "GradientBoost",
            "GradientBoost Hypertuned",
        ],
        "Train_Accuracy": acc_train,
        "Test_Accuracy": acc_test,
        "Train_Recall": recall_train,
        "Test_Recall": recall_test,
        "Train_Precision": precision_train,
        "Test_Precision": precision_test,
    }
)

# Sorting models in decreasing order of test recall
comparison_frame
# Out:
#                             Model  Train_Accuracy  Test_Accuracy  \
# 0             Logistic Regression           0.812          0.815
# 1  Logistic Regression Hypertuned           0.812          0.815
# 2                   Random Forest           0.999          0.852
# 3        Random Forest Hypertuned           0.953          0.848
# 4                   GradientBoost           0.820          0.823
# 5        GradientBoost Hypertuned           0.841          0.835
#
#    Train_Recall  Test_Recall  Train_Precision  Test_Precision
# 0         0.621        0.629            0.834           0.836
# 1         0.621        0.629            0.834           0.836
# 2         0.998        0.721            0.999           0.863
# 3         0.893        0.708            0.980           0.863
# 4         0.623        0.633            0.856           0.859
# 5         0.707        0.702            0.842           0.831

# %% [markdown]
# ## Feature Importances

# %%
feature_names = X_train.columns
importances = rf[1].feature_importances_
indices = np.argsort(importances)

# Sort the indices in descending order of importances to get the top 10 features
top_indices = np.argsort(importances)[::-1][:10]
top_feature_names = [feature_names[i] for i in top_indices]
top_importances = importances[top_indices]

plt.figure(figsize=(12, 8))
plt.title("Top 10 Feature Importances")
plt.barh(range(len(top_indices)), top_importances, color="violet", align="center")
plt.yticks(range(len(top_indices)), top_feature_names)
plt.xlabel("Relative Importance")
plt.show()
